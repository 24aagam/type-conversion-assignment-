# %%
# 1. Covert an integer to a floating-point number.

Int = 45
print(float(Int))
# Out:
# 45.0

# %%
# 2. Covert a float to an integer.

Float = 4.5
print(int(Float))
# Out:
# 4

# %%
# 3. Covert an integer to a string

Int = 23
print(str(Int))
# Out:
# 23

# %%
# 4. Covert a list to a tuple

List = [1,2,3,13,20]
print(tuple(List))
# Out:
# (1, 2, 3, 13, 20)

# %%
# 5. Covert a tuple to a list

Tuple = (1,2,3,13,20)
print(list(Tuple))
# Out:
# [1, 2, 3, 13, 20]

# %%
# 6. Covert a decimal number to a binary

decimal_no = 15
print(bin(decimal_no))
# Out:
# 0b1111

# %%
# 7. Covert a non-zero number to a boolean

non_zero = 10
print(bool(non_zero))
# Out:
# True
